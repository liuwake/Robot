# %% [markdown]
# # 颜色蒙版，绿色屏幕
#
# ### 导入资源

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import numpy as np
import cv2

# %matplotlib inline

# %% [markdown]
# ### 读入并显示图像

# %%
# Read in the image
image = mpimg.imread('images/car_green_screen.jpg')

# Print out the image dimensions (height, width, and depth (color))
print('Image dimensions:', image.shape)

# Display the image
plt.imshow(image)
# Out:
# Image dimensions: (450, 660, 3)

# %% [markdown]
# ### 定义颜色阈值

# %%
# Define our color selection boundaries in RGB values
lower_green = np.array([0,180,0]) 
upper_green = np.array([100,255,100])

# %% [markdown]
# ### 创建一个蒙版

# %%
# Define the masked area
mask = cv2.inRange(image, lower_green, upper_green)

# Vizualize the mask
plt.imshow(mask, cmap='gray')

# %%
# Mask the image to let the car show through
masked_image = np.copy(image)

masked_image[mask != 0] = [0, 0, 0]

# Display it!
plt.imshow(masked_image)

# %% [markdown]
# ## TODO: 添加蒙版并添加背景图像

# %%
image2 = mpimg.imread('images/sky.jpg')
plt.imshow(image2)

# %%
# Load in a background image, and convert it to RGB 
background_image = np.copy(image2)
print('Background image dimensions:', background_image.shape)
plt.imshow(background_image)

## TODO: Crop it or resize the background to be the right size (450x660)
background_image = background_image[100:550, 0:660, :]

## TODO: Mask the cropped background so that the pizza area is blocked
# Hint mask the opposite area of the previous image
background_image[mask == 0] = [0, 0, 0]

## TODO: Display the background and make sure 
plt.imshow(background_image)
# Out:
# Background image dimensions: (575, 1024, 3)

# %% [markdown]
# ### TODO:  创建一个完整的图像

# %%
## TODO: Add the two images together to create a complete image!
total_image = np.copy(background_image)

total_image += masked_image
plt.imshow(total_image)
